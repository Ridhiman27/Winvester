# %%
# Motilal Oswal Focused 25 Fund (MOF25) - Direct Plan Dividend Option
# Motilal Oswal Focused 25 Fund (MOF25) - Regular Plan Dividend Option
# Motilal Oswal Focused 25 Fund (MOF25)- Direct Plan Growth Option
# Motilal Oswal Focused 25 Fund (MOF25)- Regular Plan Growth Option

# SBI FOCUSED EQUITY FUND - DIRECT PLAN - DIVIDEND
# SBI FOCUSED EQUITY FUND - DIRECT PLAN -GROWTH
# SBI FOCUSED EQUITY FUND - REGULAR  PLAN - DIVIDEND
# SBI FOCUSED EQUITY FUND - REGULAR PLAN -GROWTH

# Baroda Banking And Financial Services Fund - Plan A - Bonus Option
# Baroda Banking and Financial Services Fund - Plan A - Dividend
# Baroda Banking and Financial Services Fund - Plan A - Growth Option

# Sundaram Select Focus - Direct Plan - Dividend Option
# Sundaram Select Focus - Direct Plan - Growth Option
# Sundaram Select Focus-Dividend

# Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Dividend
# Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Growth
# Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Dividend
# Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Growth

# HDFC Focused 30 Fund - DIVIDEND
# HDFC Focused 30 Fund - GROWTH
# HDFC Focused 30 Fund -Direct Plan - Dividend Option

# ICICI Prudential Focused Equity Fund - Direct Plan - Dividend
# ICICI Prudential Focused Equity Fund - Direct Plan - Growth
# ICICI Prudential Focused Equity Fund - Dividend

funds = ["Motilal Oswal Focused 25 Fund (MOF25) - Direct Plan Dividend Option","Motilal Oswal Focused 25 Fund (MOF25) - Regular Plan Dividend Option","Motilal Oswal Focused 25 Fund (MOF25)- Direct Plan Growth Option","Motilal Oswal Focused 25 Fund (MOF25)- Regular Plan Growth Option","SBI FOCUSED EQUITY FUND - DIRECT PLAN - DIVIDEND","SBI FOCUSED EQUITY FUND - DIRECT PLAN -GROWTH","SBI FOCUSED EQUITY FUND - REGULAR  PLAN - DIVIDEND","SBI FOCUSED EQUITY FUND - REGULAR PLAN -GROWTH","Baroda Banking And Financial Services Fund - Plan A - Bonus Option","Baroda Banking and Financial Services Fund - Plan A - Dividend","Baroda Banking and Financial Services Fund - Plan A - Growth Option","Sundaram Select Focus - Direct Plan - Dividend Option","Sundaram Select Focus - Direct Plan - Growth Option","Sundaram Select Focus-Dividend","Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Dividend","Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Growth","Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Dividend","Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Growth","HDFC Focused 30 Fund - DIVIDEND","HDFC Focused 30 Fund - GROWTH","HDFC Focused 30 Fund -Direct Plan - Dividend Option","ICICI Prudential Focused Equity Fund - Direct Plan - Dividend","ICICI Prudential Focused Equity Fund - Direct Plan - Growth","ICICI Prudential Focused Equity Fund - Dividend"]

# %%
"""
Motilal Oswal Focused 25 Fund (MOF25) - Direct Plan Dividend Option
Len of Motilal Oswal Focused 25 Fund (MOF25) - Direct Plan Dividend Option :- 1478
Motilal Oswal Focused 25 Fund (MOF25) - Regular Plan Dividend Option
Len of Motilal Oswal Focused 25 Fund (MOF25) - Regular Plan Dividend Option :- 1478
Motilal Oswal Focused 25 Fund (MOF25)- Direct Plan Growth Option
Len of Motilal Oswal Focused 25 Fund (MOF25)- Direct Plan Growth Option :- 1695
Motilal Oswal Focused 25 Fund (MOF25)- Regular Plan Growth Option
Len of Motilal Oswal Focused 25 Fund (MOF25)- Regular Plan Growth Option :- 1695
SBI FOCUSED EQUITY FUND - DIRECT PLAN - DIVIDEND
Len of SBI FOCUSED EQUITY FUND - DIRECT PLAN - DIVIDEND :- 1478
SBI FOCUSED EQUITY FUND - DIRECT PLAN -GROWTH
Len of SBI FOCUSED EQUITY FUND - DIRECT PLAN -GROWTH :- 1695
SBI FOCUSED EQUITY FUND - REGULAR  PLAN - DIVIDEND
Len of SBI FOCUSED EQUITY FUND - REGULAR  PLAN - DIVIDEND :- 1478
SBI FOCUSED EQUITY FUND - REGULAR PLAN -GROWTH
Len of SBI FOCUSED EQUITY FUND - REGULAR PLAN -GROWTH :- 1695
Baroda Banking And Financial Services Fund - Plan A - Bonus Option
Len of Baroda Banking And Financial Services Fund - Plan A - Bonus Option :- 1027
Baroda Banking and Financial Services Fund - Plan A - Dividend
Len of Baroda Banking and Financial Services Fund - Plan A - Dividend :- 1478
Baroda Banking and Financial Services Fund - Plan A - Growth Option
Len of Baroda Banking and Financial Services Fund - Plan A - Growth Option :- 1695
Sundaram Select Focus - Direct Plan - Dividend Option
Len of Sundaram Select Focus - Direct Plan - Dividend Option :- 1478
Sundaram Select Focus - Direct Plan - Growth Option
Len of Sundaram Select Focus - Direct Plan - Growth Option :- 1478
Sundaram Select Focus-Dividend
Len of Sundaram Select Focus-Dividend :- 1478
Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Dividend
Len of Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Dividend :- 1478
Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Growth
Len of Aditya Birla Sun Life Banking and Financial Services Fund - Direct Plan - Growth :- 1695
Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Dividend
Len of Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Dividend :- 1478
Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Growth
Len of Aditya Birla Sun Life Banking and Financial Services Fund - Regular Plan - Growth :- 1695
HDFC Focused 30 Fund - DIVIDEND
Len of HDFC Focused 30 Fund - DIVIDEND :- 1478
HDFC Focused 30 Fund - GROWTH
Len of HDFC Focused 30 Fund - GROWTH :- 1478
HDFC Focused 30 Fund -Direct Plan - Dividend Option
Len of HDFC Focused 30 Fund -Direct Plan - Dividend Option :- 1478
ICICI Prudential Focused Equity Fund - Direct Plan - Dividend
Len of ICICI Prudential Focused Equity Fund - Direct Plan - Dividend :- 1478
ICICI Prudential Focused Equity Fund - Direct Plan - Growth
Len of ICICI Prudential Focused Equity Fund - Direct Plan - Growth :- 1695
ICICI Prudential Focused Equity Fund - Dividend
Len of ICICI Prudential Focused Equity Fund - Dividend :- 1478
"""

# %% [markdown]
# Time Series Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import lightgbm as lgb
from pmdarima import auto_arima     
from sklearn.metrics import mean_absolute_error, mean_squared_error
import os
import pickle

# %%
list_csv = sorted(os.listdir("MutualFunds"))

# print(list_csv)


output = "Model/MF/"

dir = "MutualFunds/"


for csv in list_csv[5:]:
    print(csv)
    stock = csv.split(".")[0]

    path_csv = os.path.join(dir,csv)

    df = pd.read_csv(path_csv)
    
    df = df.rename(columns = {'Sale Price':'Sale_Price'})
    df = df.rename(columns = {'Net Asset Value':'NAV'})
    df = df.rename(columns = {'Repurchase Price':'RP'})

    df = df.set_index("Date", drop=False)
    df.reset_index(drop=True, inplace=True)

    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

    # print(df['RP'].head())
    # print(df['NAV'].head())
    # print(df['ISIN Div Reinvestment'].head())

    
    print("changing date and time")
    df.Date = pd.to_datetime(df.Date, format="%Y-%m-%d")
    df["month"] = df.Date.dt.month
    df["week"] = df.Date.dt.week
    df["day"] = df.Date.dt.day
    df["day_of_week"] = df.Date.dt.dayofweek

    df = df[df.Date <= "2018-06-29"]

    print(df.dtypes)
    df.fillna(df.mean(),inplace=True)
    df['RP'] = df['RP'].astype("float")
    df['Sale_Price'] = df['Sale_Price'].astype("float")



    # df.head(5)


    # df = df.reset_index(drop=True)
    lag_features = ["NAV", "RP"]
    window1 = 3
    window2 = 7
    window3 = 30

    df_rolled_3d = df[lag_features].rolling(window=window1, min_periods=0)
    df_rolled_7d = df[lag_features].rolling(window=window2, min_periods=0)
    df_rolled_30d = df[lag_features].rolling(window=window3, min_periods=0)

    df_mean_3d = df_rolled_3d.mean().shift(1).reset_index().astype(np.float32)
    df_mean_7d = df_rolled_7d.mean().shift(1).reset_index().astype(np.float32)
    df_mean_30d = df_rolled_30d.mean().shift(1).reset_index().astype(np.float32)

    df_std_3d = df_rolled_3d.std().shift(1).reset_index().astype(np.float32)
    df_std_7d = df_rolled_7d.std().shift(1).reset_index().astype(np.float32)
    df_std_30d = df_rolled_30d.std().shift(1).reset_index().astype(np.float32)


    for feature in lag_features:
        df[f"{feature}_mean_lag{window1}"] = df_mean_3d[feature]
        df[f"{feature}_mean_lag{window2}"] = df_mean_7d[feature]
        df[f"{feature}_mean_lag{window3}"] = df_mean_30d[feature]
        
        df[f"{feature}_std_lag{window1}"] = df_std_3d[feature]
        df[f"{feature}_std_lag{window2}"] = df_std_7d[feature]
        df[f"{feature}_std_lag{window3}"] = df_std_30d[feature]

    df.fillna(df.mean(),inplace=True)
    df.set_index("Date", drop=False)
    # df.head()


    df_train = df[df.Date < "2022"]

    exogenous_features = ["NAV_mean_lag3", "NAV_std_lag3", "RP_mean_lag3", "RP_std_lag3",
                        "NAV_mean_lag7", "NAV_std_lag7", "RP_mean_lag7", "RP_std_lag7",
                        "NAV_mean_lag30", "NAV_std_lag30", "RP_mean_lag30", "RP_std_lag30",
                        "month", "week", "day", "day_of_week"]
    # df.head()

    print("Training started")
    model = auto_arima(df_train.Sale_Price, exogenous=df_train[exogenous_features], trace=True, error_action="ignore", suppress_warnings=True)
    model.fit(df_train.Sale_Price, exogenous=df_train[exogenous_features])

    path = os.path.join(output,stock)

    with open(path,'wb') as f:
        pickle.dump(model,f)
    print("model_saved")

    # forecast = model.predict(n_periods=len(df_valid), exogenous=df_valid[exogenous_features])
    # df_valid["Forecast_ARIMAX"] = forecast
    # df_valid[["Sale_Price", "Forecast_ARIMAX"]].plot(figsize=(14, 7))
# Out:
# Baroda_Banking_and_Financial_Services_Fund_-_Plan_A_-_Dividend.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-458.411, Time=2.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-453.911, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-452.728, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-452.848, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-455.890, Time=0.19 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-452.325, Time=0.79 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-452.558, Time=0.77 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-452.187, Time=2.44 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-456.602, Time=3.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-452.495, Time=0.62 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-450.388, Time=0.72 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-450.867, Time=1.80 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-454.745, Time=3.46 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-461.479, Time=1.49 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-454.302, Time=0.42 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-454.536, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-454.168, Time=1.30 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-459.240, Time=1.91 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-454.475, Time=0.46 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-452.373, Time=0.68 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=-452.846, Time=0.54 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-458.240, Time=2.57 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 26.483 seconds
# model_saved
# Baroda_Banking_and_Financial_Services_Fund_-_Plan_A_-_Growth_Option.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                     object
# Sale_Price                             object
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-474.287, Time=1.69 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-472.574, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-471.922, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-472.110, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-473.820, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-471.465, Time=1.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-471.566, Time=0.71 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=3.11 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-472.511, Time=3.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-472.357, Time=0.92 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-469.520, Time=1.18 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-469.746, Time=0.41 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-470.656, Time=3.15 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=1.54 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 17.386 seconds
# model_saved
# HDFC_Focused_30_Fund_-Direct_Plan_-_Dividend_Option.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1896.355, Time=0.68 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4537.291, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=3608.527, Time=0.38 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=7660.440, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1894.744, Time=1.12 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=3041.956, Time=0.94 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1892.816, Time=0.68 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1894.856, Time=0.71 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1893.689, Time=0.16 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 5.806 seconds
# model_saved
# HDFC_Focused_30_Fund_-_DIVIDEND.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1774.235, Time=1.43 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1766.244, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1768.243, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1768.243, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1765.477, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1770.243, Time=0.22 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.196 seconds
# model_saved
# HDFC_Focused_30_Fund_-_GROWTH.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# Training started
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.39 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4159.486, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4161.469, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4161.469, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4158.042, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4163.482, Time=0.28 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.200 seconds
# model_saved
# ICICI_Prudential_Focused_Equity_Fund_-_Direct_Plan_-_Dividend.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-133.613, Time=1.31 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-137.950, Time=0.27 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-137.813, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-137.909, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-139.846, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-137.593, Time=0.61 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.523 seconds
# model_saved
# ICICI_Prudential_Focused_Equity_Fund_-_Direct_Plan_-_Growth.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# Training started
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-238.344, Time=2.37 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-238.312, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-238.654, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-238.847, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-238.833, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-240.861, Time=0.79 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-235.986, Time=0.34 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-238.005, Time=1.42 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-238.184, Time=0.46 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-237.980, Time=0.33 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-241.462, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-239.508, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-239.313, Time=0.12 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-239.502, Time=0.36 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-238.114, Time=0.32 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-238.736, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=-238.538, Time=0.09 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-238.468, Time=0.83 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 8.663 seconds
# model_saved
# ICICI_Prudential_Focused_Equity_Fund_-_Dividend.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-404.850, Time=1.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-409.204, Time=0.38 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-408.498, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-408.597, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-410.943, Time=0.19 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-407.704, Time=0.25 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.201 seconds
# model_saved
# Motilal_Oswal_Focused_25_Fund_(MOF25)-_Direct_Plan_Growth_Option.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# Training started
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-701.789, Time=3.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-694.057, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-703.260, Time=0.31 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-704.297, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-693.552, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-703.966, Time=0.77 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-703.562, Time=0.41 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-704.015, Time=2.29 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-704.266, Time=0.15 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 7.564 seconds
# model_saved
# Motilal_Oswal_Focused_25_Fund_(MOF25)-_Regular_Plan_Growth_Option.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-780.982, Time=1.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-775.007, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-784.222, Time=0.33 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-785.276, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-775.076, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-784.978, Time=0.58 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-784.578, Time=0.44 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-784.996, Time=1.78 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-785.708, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-785.298, Time=0.45 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-784.888, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-784.667, Time=0.18 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-784.512, Time=0.52 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 6.330 seconds
# model_saved
# Motilal_Oswal_Focused_25_Fund_(MOF25)_-_Direct_Plan_Dividend_Option.csv
# changing date and time
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-701.146, Time=1.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-699.216, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-703.959, Time=0.25 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-704.254, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-700.789, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-704.470, Time=0.63 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-702.948, Time=1.19 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-702.901, Time=1.22 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-702.664, Time=0.65 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-702.345, Time=0.36 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-706.078, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-705.887, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-705.595, Time=0.26 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-704.571, Time=0.43 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-704.522, Time=0.40 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-704.283, Time=0.32 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=-703.966, Time=0.19 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-702.780, Time=0.88 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 9.695 seconds
# model_saved
# Motilal_Oswal_Focused_25_Fund_(MOF25)_-_Regular_Plan_Dividend_Option.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-765.517, Time=1.84 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-763.984, Time=0.21 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-768.423, Time=0.31 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-768.703, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-765.789, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-768.898, Time=0.54 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-767.318, Time=0.67 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-767.277, Time=1.00 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-767.114, Time=0.49 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-766.801, Time=0.26 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-770.718, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-770.534, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-770.255, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-769.145, Time=0.50 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-769.103, Time=0.85 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-768.938, Time=0.20 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=-768.626, Time=0.13 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-767.348, Time=0.90 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 8.752 seconds
# model_saved
# SBI_FOCUSED_EQUITY_FUND_-_DIRECT_PLAN_-GROWTH.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2096.173, Time=1.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2110.422, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2091.025, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2090.266, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2112.071, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2092.234, Time=0.47 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2092.238, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2094.242, Time=0.34 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2091.072, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 3.198 seconds
# model_saved
# SBI_FOCUSED_EQUITY_FUND_-_DIRECT_PLAN_-_DIVIDEND.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=398.660, Time=1.97 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=397.860, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=393.919, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=394.100, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=396.047, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=395.818, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=395.853, Time=0.46 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=397.110, Time=1.02 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=392.081, Time=0.13 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=393.978, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=394.013, Time=0.36 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=392.265, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=395.271, Time=0.57 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 5.676 seconds
# model_saved
# SBI_FOCUSED_EQUITY_FUND_-_REGULAR_PLAN_-GROWTH.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# Training started
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2040.568, Time=1.16 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2054.877, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2035.420, Time=0.19 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2034.661, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2055.966, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2036.629, Time=0.31 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2036.633, Time=0.27 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2038.638, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2035.038, Time=0.09 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 2.725 seconds
# model_saved
# SBI_FOCUSED_EQUITY_FUND_-_REGULAR__PLAN_-_DIVIDEND.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-125.501, Time=2.68 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-126.414, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-130.117, Time=0.28 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-129.942, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-128.337, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-128.219, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-128.182, Time=0.51 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-126.236, Time=0.35 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-132.048, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=-130.152, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-130.103, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-131.873, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-128.882, Time=0.87 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 5.866 seconds
# model_saved
# Sundaram_Select_Focus-Dividend.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# Training started
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-1241.693, Time=2.53 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1239.031, Time=0.31 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1240.383, Time=0.56 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1240.618, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1241.026, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-1237.846, Time=1.35 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-1237.859, Time=1.62 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-1243.584, Time=4.29 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-1236.597, Time=1.17 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-1241.251, Time=5.82 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-1237.659, Time=3.88 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-1243.875, Time=3.08 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-1236.380, Time=1.68 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-1238.305, Time=3.22 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-1234.816, Time=2.67 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-1236.404, Time=3.41 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-1245.731, Time=1.77 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-1238.376, Time=1.01 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-1243.689, Time=1.36 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-1240.132, Time=1.75 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=-1240.301, Time=1.67 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-1239.792, Time=0.35 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=-1236.812, Time=1.13 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-1245.590, Time=1.67 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=-1240.163, Time=2.51 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 49.235 seconds
# model_saved
# Sundaram_Select_Focus_-_Direct_Plan_-_Dividend_Option.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                  object
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-1220.094, Time=2.57 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1217.443, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1218.795, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1219.029, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1219.440, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-1216.252, Time=1.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-1216.264, Time=1.36 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-1222.107, Time=3.55 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-1214.996, Time=0.73 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-1220.760, Time=3.17 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-1216.026, Time=3.23 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-1222.448, Time=2.79 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-1214.783, Time=1.60 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-1216.689, Time=3.09 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-1213.206, Time=2.20 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-1214.465, Time=3.23 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-1224.514, Time=2.08 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-1216.780, Time=0.98 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-1222.092, Time=1.14 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-1218.187, Time=1.82 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=-1218.692, Time=1.62 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-1218.209, Time=0.39 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=-1215.204, Time=1.24 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-1224.120, Time=1.41 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=-1218.521, Time=2.57 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 42.659 seconds
# model_saved
# Sundaram_Select_Focus_-_Direct_Plan_-_Growth_Option.csv
# changing date and time
# Scheme Code                             int64
# Scheme Name                            object
# ISIN Div Payout/ISIN Growth            object
# ISIN Div Reinvestment                 float64
# NAV                                   float64
# RP                                    float64
# Sale_Price                            float64
# Date                           datetime64[ns]
# month                                   int64
# week                                    int64
# day                                     int64
# day_of_week                             int64
# dtype: object
# Training started
# Performing stepwise search to minimize aic
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:36: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df.Date.dt.week
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:43: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(),inplace=True)
# C:\Users\ridhi\AppData\Local\Temp\ipykernel_12716\3449445077.py:80: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace=True)
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2542.973, Time=1.76 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2543.171, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2539.567, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2539.222, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2543.665, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2539.228, Time=0.33 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2540.440, Time=0.24 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2541.057, Time=0.98 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2539.376, Time=0.10 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 3.832 seconds
# model_saved

# %%
import pickle
model2 = pickle.load(open('Model\MF\Baroda_Banking_and_Financial_Services_Fund_-_Plan_A_-_Dividend','rb'))

# %%
model2.predict(20,60)
# Out:
# 863    16.097822
# 864    16.061509
# 865    16.083550
# 866    16.101386
# 867    16.064965
# 868    16.077192
# 869    16.103181
# 870    16.069779
# 871    16.071469
# 872    16.103113
# 873    16.075495
# 874    16.066850
# 875    16.101249
# 876    16.081591
# 877    16.063694
# 878    16.097809
# 879    16.087533
# 880    16.062224
# 881    16.093138
# 882    16.092816
# dtype: float64
